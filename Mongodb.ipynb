# %% [markdown]
# Installing and connecting to MongoDB

# %%
# !pip install "pymongo[srv]"
# Out:
# ...
#   Obtaining dependency information for pymongo[srv] from https://files.pythonhosted.org/packages/14/8a/96b6a2c9a6ca2d28e3426d8298a914214f5368964c764d1e1095fcbf68e1/pymongo-4.7.1-cp311-cp311-macosx_11_0_arm64.whl.metadata
# ...
#   Obtaining dependency information for dnspython<3.0.0,>=1.16.0 from https://files.pythonhosted.org/packages/87/a1/8c5287991ddb8d3e4662f71356d9656d91ab3a36618c3dd11b280df0d255/dnspython-2.6.1-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 3.0 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.3/486.3 kB 3.6 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import pandas as pd
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
# Out:
# /Users/ushajain/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
uri = "mongodb+srv://ushajain:AyQwtRX87oE5Beok@electricvehicle.i7ivedb.mongodb.net/?retryWrites=true&w=majority&appName=ElectricVehicle"

mongoC = MongoClient(uri, server_api=ServerApi('1'))
#checking for successful connection
try:
    mongoC.admin.command('ping')
    print("MongoDB Connected!")
except Exception as e:
    print(e)
# Out:
# MongoDB Connected!

# %%
df = pd.read_csv('Electric_Vehicle_Population_Size_History_By_County.csv')
df.head()
# Out:
#                Date        County State Vehicle Primary Use  \
# 0     April 30 2022     Wahkiakum    WA               Truck
# 1       May 31 2017         Adams    WA               Truck
# 2   October 31 2019        Collin    TX           Passenger
# 3   January 31 2024      Franklin    WA               Truck
# 4  February 28 2018  Grays Harbor    WA               Truck
#
#    Battery Electric Vehicles (BEVs)  Plug-In Hybrid Electric Vehicles (PHEVs)  \
# 0                                 0                                         0
# 1                                 0                                         0
# 2                                 2                                         1
# 3                                10                                         0
# 4                                 0                                         0
#
#    Electric Vehicle (EV) Total  Non-Electric Vehicle Total  Total Vehicles  \
# ...

# %%
df.describe()
# Out:
#        Battery Electric Vehicles (BEVs)  \
# count                      21207.000000
# mean                         220.251851
# std                         2321.030689
# min                            0.000000
# 25%                            0.000000
# 50%                            1.000000
# 75%                            3.000000
# max                        73550.000000
#
#        Plug-In Hybrid Electric Vehicles (PHEVs)  Electric Vehicle (EV) Total  \
# count                              21207.000000                 21207.000000
# mean                                  80.468053                   300.719904
# std                                  654.091391                  2965.712772
# min                                    0.000000                     0.000000
# 25%                                    0.000000                     1.000000
# 50%                                    1.000000                     1.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21207 entries, 0 to 21206
# Data columns (total 10 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Date                                      21207 non-null  object
#  1   County                                    21120 non-null  object
#  2   State                                     21120 non-null  object
#  3   Vehicle Primary Use                       21207 non-null  object
#  4   Battery Electric Vehicles (BEVs)          21207 non-null  int64
#  5   Plug-In Hybrid Electric Vehicles (PHEVs)  21207 non-null  int64
#  6   Electric Vehicle (EV) Total               21207 non-null  int64
#  7   Non-Electric Vehicle Total                21207 non-null  int64
#  8   Total Vehicles                            21207 non-null  int64
#  9   Percent Electric Vehicles                 21207 non-null  float64
# ...

# %%
dataToDict = df.to_dict("records")

# %%
uri = "mongodb+srv://ushajain:AyQwtRX87oE5Beok@electricvehicle.i7ivedb.mongodb.net/?retryWrites=true&w=majority&appName=ElectricVehicle"

mongoC =  MongoClient(uri)
database = mongoC['ElectricVehicle']
column = database['ElectricVehicleData']
dataToDict = df.to_dict("records")
column.insert_many(dataToDict) #inserting data in collection
# Out:
# InsertManyResult([ObjectId('6632f82e70d2fd68d9dc45ce'), ObjectId('6632f82e70d2fd68d9dc45cf'), ObjectId('6632f82e70d2fd68d9dc45d0'), ObjectId('6632f82e70d2fd68d9dc45d1'), ObjectId('6632f82e70d2fd68d9dc45d2'), ObjectId('6632f82e70d2fd68d9dc45d3'), ObjectId('6632f82e70d2fd68d9dc45d4'), ObjectId('6632f82e70d2fd68d9dc45d5'), ObjectId('6632f82e70d2fd68d9dc45d6'), ObjectId('6632f82e70d2fd68d9dc45d7'), ObjectId('6632f82e70d2fd68d9dc45d8'), ObjectId('6632f82e70d2fd68d9dc45d9'), ObjectId('6632f82e70d2fd68d9dc45da'), ObjectId('6632f82e70d2fd68d9dc45db'), ObjectId('6632f82e70d2fd68d9dc45dc'), ObjectId('6632f82e70d2fd68d9dc45dd'), ObjectId('6632f82e70d2fd68d9dc45de'), ObjectId('6632f82e70d2fd68d9dc45df'), ObjectId('6632f82e70d2fd68d9dc45e0'), ObjectId('6632f82e70d2fd68d9dc45e1'), ObjectId('6632f82e70d2fd68d9dc45e2'), ObjectId('6632f82e70d2fd68d9dc45e3'), ObjectId('6632f82e70d2fd68d9dc45e4'), ObjectId('6632f82e70d2fd68d9dc45e5'), ObjectId('6632f82e70d2fd68d9dc45e6'), ObjectId('6632f82e70d2fd68d9dc
# ...

# %%
df['State'].unique()
# Out:
# array(['WA', 'TX', 'VA', 'MT', 'NC', 'RI', 'CO', 'CA', 'MD', 'PA', 'AK',
#        'NH', 'UT', 'OR', 'MA', 'FL', 'AL', 'SC', 'AZ', 'IL', 'NY', 'MO',
#        'GA', nan, 'IN', 'KY', 'HI', 'ID', 'IA', 'NJ', 'NE', 'ND', 'KS',
#        'NV', 'MI', 'CT', 'ME', 'TN', 'DC', 'OK', 'OH', 'MN', 'AR', 'PR',
#        'LA', 'MS', 'SD', 'WY', 'WI', 'NM', 'DE'], dtype=object)

# %%
dfTexas = df[df['State']=='TX'].reset_index(drop=True)
dfTexas
# Out:
#                    Date      County State Vehicle Primary Use  \
# 0       October 31 2019      Collin    TX           Passenger
# 1       January 31 2020   Fort Bend    TX           Passenger
# 2        August 31 2022  Williamson    TX           Passenger
# 3      December 31 2022      Nueces    TX           Passenger
# 4      November 30 2022      Travis    TX           Passenger
# ...                 ...         ...   ...                 ...
# 1078   February 28 2017     Hidalgo    TX           Passenger
# 1079       July 31 2021     Wichita    TX           Passenger
# 1080  September 30 2018      Dallas    TX           Passenger
# 1081   February 28 2023      Nueces    TX           Passenger
# 1082  September 30 2018      Nueces    TX           Passenger
#
#       Battery Electric Vehicles (BEVs)  \
# 0                                    2
# 1                                    1
# 2                                    0
# 3                                    0
# ...

# %%
dfIndiana = df[df['State']=='IN'].reset_index(drop=True)

# %%
dfOhio = df[df['State']=='OH'].reset_index(drop=True)

# %%
dfNewYork = df[df['State']=='NY'].reset_index(drop=True)

# %%
uri = "mongodb+srv://ushajain:AyQwtRX87oE5Beok@electricvehicle.i7ivedb.mongodb.net/?retryWrites=true&w=majority&appName=ElectricVehicle"
mongoC =  MongoClient(uri)
inState = database['stateOhioRecords']
dfDict = dfOhio.to_dict("records")
inState.insert_many(dfDict)
# Out:
# InsertManyResult([ObjectId('6633186a70d2fd68d9dca20d'), ObjectId('6633186a70d2fd68d9dca20e'), ObjectId('6633186a70d2fd68d9dca20f'), ObjectId('6633186a70d2fd68d9dca210'), ObjectId('6633186a70d2fd68d9dca211'), ObjectId('6633186a70d2fd68d9dca212'), ObjectId('6633186a70d2fd68d9dca213'), ObjectId('6633186a70d2fd68d9dca214'), ObjectId('6633186a70d2fd68d9dca215'), ObjectId('6633186a70d2fd68d9dca216'), ObjectId('6633186a70d2fd68d9dca217'), ObjectId('6633186a70d2fd68d9dca218'), ObjectId('6633186a70d2fd68d9dca219'), ObjectId('6633186a70d2fd68d9dca21a'), ObjectId('6633186a70d2fd68d9dca21b'), ObjectId('6633186a70d2fd68d9dca21c'), ObjectId('6633186a70d2fd68d9dca21d'), ObjectId('6633186a70d2fd68d9dca21e'), ObjectId('6633186a70d2fd68d9dca21f'), ObjectId('6633186a70d2fd68d9dca220'), ObjectId('6633186a70d2fd68d9dca221'), ObjectId('6633186a70d2fd68d9dca222'), ObjectId('6633186a70d2fd68d9dca223'), ObjectId('6633186a70d2fd68d9dca224'), ObjectId('6633186a70d2fd68d9dca225'), ObjectId('6633186a70d2fd68d9dc
# ...

# %%
uri = "mongodb+srv://ushajain:AyQwtRX87oE5Beok@electricvehicle.i7ivedb.mongodb.net/?retryWrites=true&w=majority&appName=ElectricVehicle"
mongoC =  MongoClient(uri)
nyState = database['stateNewYorkRecords']
dfDict = dfNewYork.to_dict("records")
nyState.insert_many(dfDict)
# Out:
# InsertManyResult([ObjectId('6633153370d2fd68d9dc9b3d'), ObjectId('6633153370d2fd68d9dc9b3e'), ObjectId('6633153370d2fd68d9dc9b3f'), ObjectId('6633153370d2fd68d9dc9b40'), ObjectId('6633153370d2fd68d9dc9b41'), ObjectId('6633153370d2fd68d9dc9b42'), ObjectId('6633153370d2fd68d9dc9b43'), ObjectId('6633153370d2fd68d9dc9b44'), ObjectId('6633153370d2fd68d9dc9b45'), ObjectId('6633153370d2fd68d9dc9b46'), ObjectId('6633153370d2fd68d9dc9b47'), ObjectId('6633153370d2fd68d9dc9b48'), ObjectId('6633153370d2fd68d9dc9b49'), ObjectId('6633153370d2fd68d9dc9b4a'), ObjectId('6633153370d2fd68d9dc9b4b'), ObjectId('6633153370d2fd68d9dc9b4c'), ObjectId('6633153370d2fd68d9dc9b4d'), ObjectId('6633153370d2fd68d9dc9b4e'), ObjectId('6633153370d2fd68d9dc9b4f'), ObjectId('6633153370d2fd68d9dc9b50'), ObjectId('6633153370d2fd68d9dc9b51'), ObjectId('6633153370d2fd68d9dc9b52'), ObjectId('6633153370d2fd68d9dc9b53'), ObjectId('6633153370d2fd68d9dc9b54'), ObjectId('6633153370d2fd68d9dc9b55'), ObjectId('6633153370d2fd68d9dc
# ...

# %%
uri = "mongodb+srv://ushajain:AyQwtRX87oE5Beok@electricvehicle.i7ivedb.mongodb.net/?retryWrites=true&w=majority&appName=ElectricVehicle"
mongoC =  MongoClient(uri)
nyState = database['stateTexasRecords']
dfDict = dfTexas.to_dict("records")
nyState.insert_many(dfDict)
# Out:
# InsertManyResult([ObjectId('6633155f70d2fd68d9dc9dd1'), ObjectId('6633155f70d2fd68d9dc9dd2'), ObjectId('6633155f70d2fd68d9dc9dd3'), ObjectId('6633155f70d2fd68d9dc9dd4'), ObjectId('6633155f70d2fd68d9dc9dd5'), ObjectId('6633155f70d2fd68d9dc9dd6'), ObjectId('6633155f70d2fd68d9dc9dd7'), ObjectId('6633155f70d2fd68d9dc9dd8'), ObjectId('6633155f70d2fd68d9dc9dd9'), ObjectId('6633155f70d2fd68d9dc9dda'), ObjectId('6633155f70d2fd68d9dc9ddb'), ObjectId('6633155f70d2fd68d9dc9ddc'), ObjectId('6633155f70d2fd68d9dc9ddd'), ObjectId('6633155f70d2fd68d9dc9dde'), ObjectId('6633155f70d2fd68d9dc9ddf'), ObjectId('6633155f70d2fd68d9dc9de0'), ObjectId('6633155f70d2fd68d9dc9de1'), ObjectId('6633155f70d2fd68d9dc9de2'), ObjectId('6633155f70d2fd68d9dc9de3'), ObjectId('6633155f70d2fd68d9dc9de4'), ObjectId('6633155f70d2fd68d9dc9de5'), ObjectId('6633155f70d2fd68d9dc9de6'), ObjectId('6633155f70d2fd68d9dc9de7'), ObjectId('6633155f70d2fd68d9dc9de8'), ObjectId('6633155f70d2fd68d9dc9de9'), ObjectId('6633155f70d2fd68d9dc
# ...

# %%
column = database['stateNewYorkRecords']
output = column.update_many({}, {'$unset': {'State': ""}})
print(f"No of updates: {output.modified_count}")

column = database['stateIndianaRecords']
output = column.update_many({}, {'$unset': {'State': ""}})
print(f"No of updates: {output.modified_count}")
# Out:
# No of updates: 0
# No of updates: 414
# No of updates: 902

# %%
column = database['stateOhioRecords']
output = column.update_many({}, {'$unset': {'State': ""}})
print(f"No of updates: {output.modified_count}")
# Out:
# No of updates: 138
